# %%
import cerespp
import glob

# %%
files = glob.glob('HD10700*.fits')
files
# Out:
# ['HD10700_1.fits', 'HD10700_2.fits']

# %%
lines = ['CaHK', 'Ha', 'HeI', 'NaID1D2']
cerespp.line_plot_from_file(files[0], lines, './', 'HD10700')
# Out:
# Correcting spectrum to rest frame. (This could take a while)
# Merging echelle spectra.
# Plotting line CaHK
# Plotting line Ha
# Plotting line HeI
# Plotting line NaID1D2

# %%
cerespp.get_activities(files, './HD10700_activities.dat')
# Out:
# 100%|██████████| 2/2 [06:15<00:00, 187.67s/it]
# (array([[ 2.45885153e+06,  1.78677769e-01,  9.75936570e-03,
#           2.20531541e-01,  2.59222965e-04,  1.01808709e+00,
#           1.88528065e-05,  4.41460252e-01,  9.53450467e-05,
#          -1.35000000e-02,  5.10000000e-03,  8.88442699e+00,
#           7.03971119e-03,  6.80000000e-01],
#         [ 2.45885253e+06,  1.79366780e-01,  9.78316179e-03,
#           2.20897072e-01,  2.49087390e-04,  1.00923949e+00,
#           1.83605962e-05,  4.55790288e-01,  8.97277919e-05,
#          -1.08000000e-02,  5.10000000e-03,  8.87761217e+00,
#           6.95187166e-03,  6.80000000e-01]]),
#  'bjd S e_S Halpha e_Halpha HeI e_HeI NaID1D2 e_NaID1D2 BIS e_BIS FWHM e_FWHM CONTRAST')
